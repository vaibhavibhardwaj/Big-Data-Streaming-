# %% [markdown]
# # FIT5202 - Data processing for Big Data
# Name : Vaibhavi Bhardwaj
#
# Student Id : 30154987
#
# Email id : vbha0006@student.monash.edu
#
#
# ## 2.1 Process Event Consumer (5%)
#
# Write a python program that consumes the process events using kafka consumer, visualise
# the record counts in real time. Save the file as
# Assignment-2B-Task2_process_consumer.ipynb.
# Your program should get the count of records arriving in the last 2-minutes (use the
# processing time) for each machine, and use line charts to visualise.
# - Hint - x-axis can be used to represent the timeline, while y-axis can be used to
# represent the count; each machine’s line data can be represented in different color
# legends

# %%
# import statements
from time import sleep
from kafka import KafkaConsumer
import datetime as dt
import matplotlib
import matplotlib.pyplot as plt
import time

# this line is needed for the inline display of graphs in Jupyter Notebook
# %matplotlib notebook

# topic of this consumer 
topic = 'A2Bprocess'

def connect_kafka_consumer():
    _consumer = None
    try:
         _consumer = KafkaConsumer(topic,
                                   consumer_timeout_ms=10000, # stop iteration if no message after 10 sec
                                   auto_offset_reset='earliest', # comment this if you don't want to consume earliest available message
                                   bootstrap_servers=['localhost:9092'],
                                   api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka')
        print(str(ex))
    finally:
        return _consumer

def init_plots():
    try:
        width = 12
        height = 5
        fig = plt.figure(figsize=(width,height)) # create new figure
        ax = fig.add_subplot(111) # adding the subplot axes to the given grid position
        fig.suptitle('Real-time uniform stream data visualization') # giving figure a title
        ax.set_xlabel('Time')
        ax.set_ylabel('Value')
        ax.set_ylim(0,110) 
        fig.show() # displaying the figure
        fig.canvas.draw() # drawing on the canvas
        return fig, ax
    except Exception as ex:
        print(str(ex))
    
    
# Consuming mesasge function to get data from the publisher 
def consume_messages(consumer, fig, ax):
    try:
        # container for x and y values for plotting
        x, y4 ,y5, y6, y7,y8= [], [], [], [], [], []
        
        # initialiisng the 2 minute counter to store data
        end_t = time.time() + 60*2
        
        # let f be initial index of x...
        # which is 0 as we have no data in x 
        f =  0 
        
        # iterating through the array 
        for message in consumer:
            #print(message)
            # evaluating the mesage value  
            data = eval(str(message.value.decode('utf-8')))
            
            # appending data into the list of x and y for plotting later
            # i.e. collecting data for 2 minutes 
            x.append(int(data[5])) # time stamp             
            y4.append(int(data[0])) # machine 4
            y5.append(int(data[1])) # machine 5
            y6.append(int(data[2])) # machine 6
            y7.append(int(data[3])) # machine 7 
            y8.append(int(data[4])) # mavhine 8


            # we start plotting only when we have have collected data for 2 minutes 
            # checking if currect time has crossed 2 min timer 
            # if yes let's print 
            if time.time()>end_t:
                
                # now printing 5 datapoints at a time 
                for r in range(f,len(x),5):
                    
                    #print(f,len(x))
                    # collecting data from x 
                    x1 = x[r:r+5]
                    # collecting data form y's for each machine
                    y41 = y4[r:r+5]
                    y51 = y5[r:r+5]
                    y61 = y6[r:r+5]
                    y71 = y7[r:r+5]
                    y81 = y8[r:r+5]

                    # clearing the previous plotted graphs
                    ax.clear()
                    # different color for each machine
                    ax.plot(x1, y41,'r--',x1,y51,'b--',x1,y61,'g--',x1,y71,'p--',x1,y81,'y--')
                    # label
                    ax.set_xlabel('Time')
                    ax.set_ylabel('Count')
                    
                    # frawing the canvas 
                    fig.canvas.draw()
                    
                    # emptying the lists for next iteration
                    x1.pop(0) # removing the item in the first position
                    y41.pop(0)
                    y51.pop(0)
                    y61.pop(0)
                    y71.pop(0)
                    y81.pop(0)
                    # sleep for 2 seconds to clearly see the plots after 5 datapoints
                    sleep(2)
                    
                # updating f the list 
                f = len(x)
                end_t = time.time() + 60*2

        plt.close('all')
    except Exception as ex:
        print(str(ex))
        
    
if __name__ == '__main__':
    
    consumer = connect_kafka_consumer()
    #print(consumer)
    fig, ax = init_plots()
    consume_messages(consumer, fig, ax)
# Out:
# <img src="data:image/png;base64,..." width="1200">
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=0, timestamp=1604196642182, timestamp_type=0, key=None, value=b'[19, 22, 38, 22, 35, 1604196641]', headers=[], checksum=306429547, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=1, timestamp=1604196647230, timestamp_type=0, key=None, value=b'[14, 36, 42, 30, 49, 1604196647]', headers=[], checksum=2245436182, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=2, timestamp=1604196652267, timestamp_type=0, key=None, value=b'[48, 10, 29, 21, 46, 1604196652]', headers=[], checksum=292702960, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=3, timestamp=1604196657326, timestamp_type=0, key=None, value=b'[38, 44, 40, 19, 19, 1604196657]', headers=[], checksum=1760853698, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=4, timestamp=1604196662382, timestamp_type=0, key=None, value=b'[27, 34, 50, 12, 19, 1604196662]', headers=[], checksum=3505121341, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=5, timestamp=1604196667449, timestamp_type=0, key=None, value=b'[35, 35, 49, 26, 14, 1604196667]', headers=[], checksum=451029899, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=6, timestamp=1604196672514, timestamp_type=0, key=None, value=b'[29, 23, 37, 26, 10, 1604196672]', headers=[], checksum=2847777667, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=7, timestamp=1604196677566, timestamp_type=0, key=None, value=b'[32, 46, 30, 30, 23, 1604196677]', headers=[], checksum=1135679107, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=8, timestamp=1604196682593, timestamp_type=0, key=None, value=b'[23, 12, 12, 15, 29, 1604196682]', headers=[], checksum=2990910792, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=9, timestamp=1604196687628, timestamp_type=0, key=None, value=b'[44, 26, 35, 32, 31, 1604196687]', headers=[], checksum=2129705347, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=10, timestamp=1604196692675, timestamp_type=0, key=None, value=b'[45, 12, 47, 19, 37, 1604196692]', headers=[], checksum=1005855383, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=11, timestamp=1604196697737, timestamp_type=0, key=None, value=b'[40, 30, 24, 25, 11, 1604196697]', headers=[], checksum=2695821693, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=12, timestamp=1604196702789, timestamp_type=0, key=None, value=b'[25, 20, 10, 35, 46, 1604196702]', headers=[], checksum=2262094841, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=13, timestamp=1604196707855, timestamp_type=0, key=None, value=b'[32, 16, 44, 21, 21, 1604196707]', headers=[], checksum=3663960299, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=14, timestamp=1604196712903, timestamp_type=0, key=None, value=b'[30, 25, 42, 30, 13, 1604196712]', headers=[], checksum=2956043178, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=15, timestamp=1604196717948, timestamp_type=0, key=None, value=b'[50, 21, 16, 27, 20, 1604196717]', headers=[], checksum=1017608094, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=16, timestamp=1604196722975, timestamp_type=0, key=None, value=b'[14, 13, 28, 32, 30, 1604196722]', headers=[], checksum=726318189, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=17, timestamp=1604196728031, timestamp_type=0, key=None, value=b'[34, 18, 26, 50, 40, 1604196727]', headers=[], checksum=1977782813, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=18, timestamp=1604196733074, timestamp_type=0, key=None, value=b'[14, 26, 31, 11, 39, 1604196733]', headers=[], checksum=1772690397, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=19, timestamp=1604196738103, timestamp_type=0, key=None, value=b'[27, 43, 14, 16, 19, 1604196738]', headers=[], checksum=1859119730, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset
serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=65, timestamp=1604196970429, timestamp_type=0, key=None, value=b'[43, 44, 49, 40, 29, 1604196970]', headers=[], checksum=4121928609, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=66, timestamp=1604196975498, timestamp_type=0, key=None, value=b'[28, 35, 47, 20, 18, 1604196975]', headers=[], checksum=2906057138, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=67, timestamp=1604196980549, timestamp_type=0, key=None, value=b'[36, 41, 10, 20, 15, 1604196980]', headers=[], checksum=4259449521, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=68, timestamp=1604196985570, timestamp_type=0, key=None, value=b'[23, 37, 32, 16, 36, 1604196985]', headers=[], checksum=2584807218, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=69, timestamp=1604196990630, timestamp_type=0, key=None, value=b'[45, 15, 38, 45, 18, 1604196990]', headers=[], checksum=4255932160, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=70, timestamp=1604196995684, timestamp_type=0, key=None, value=b'[10, 12, 33, 17, 39, 1604196995]', headers=[], checksum=1014420409, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=71, timestamp=1604197000741, timestamp_type=0, key=None, value=b'[11, 38, 42, 22, 16, 1604197000]', headers=[], checksum=4076929822, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=72, timestamp=1604197005791, timestamp_type=0, key=None, value=b'[49, 20, 25, 40, 37, 1604197005]', headers=[], checksum=2503407787, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=73, timestamp=1604197010850, timestamp_type=0, key=None, value=b'[15, 24, 11, 31, 49, 1604197010]', headers=[], checksum=4239069037, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=74, timestamp=1604197015905, timestamp_type=0, key=None, value=b'[36, 22, 38, 26, 43, 1604197015]', headers=[], checksum=1863219005, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=75, timestamp=1604197020964, timestamp_type=0, key=None, value=b'[33, 48, 48, 46, 43, 1604197020]', headers=[], checksum=2128523827, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=76, timestamp=1604197026023, timestamp_type=0, key=None, value=b'[48, 36, 33, 22, 24, 1604197025]', headers=[], checksum=3677224057, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=77, timestamp=1604197031047, timestamp_type=0, key=None, value=b'[41, 18, 32, 19, 14, 1604197031]', headers=[], checksum=2864346550, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=78, timestamp=1604197036110, timestamp_type=0, key=None, value=b'[22, 36, 24, 19, 16, 1604197036]', headers=[], checksum=827054438, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=79, timestamp=1604197041166, timestamp_type=0, key=None, value=b'[37, 14, 12, 36, 30, 1604197041]', headers=[], checksum=2261481827, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=80, timestamp=1604197046215, timestamp_type=0, key=None, value=b'[25, 46, 10, 44, 41, 1604197046]', headers=[], checksum=642973624, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=81, timestamp=1604197051253, timestamp_type=0, key=None, value=b'[41, 14, 50, 20, 47, 1604197051]', headers=[], checksum=1082966915, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=82, timestamp=1604197056283, timestamp_type=0, key=None, value=b'[19, 24, 37, 44, 32, 1604197056]', headers=[], checksum=2132594502, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=83, timestamp=1604197061334, timestamp_type=0, key=None, value=b'[33, 32, 39, 15, 10, 1604197061]', headers=[], checksum=102687171, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=84, timestamp=1604197066394, timestamp_type=0, key=None, value=b'[38, 49, 30, 14, 18, 1604197066]', headers=[], checksum=1696445994, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=85, timestamp=1604197071473, timestamp_type=0, key=None, value=b'[17, 33, 49, 23, 45, 1604197071]', headers=[], checksum=3049301881, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=86, timestamp=1604197076505, timestamp_type=0, key=None, value=b'[28, 48, 10, 10, 37, 1604197076]', headers=[], checksum=2943659425, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=87, timestamp=1604197081574, timestamp_type=0, key=None, value=b'[17, 44, 49, 27, 44, 1604197081]', headers=[], checksum=1501336377, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=88, timestamp=1604197086626, timestamp_type=0, key=None, value=b'[14, 41, 42, 27, 18, 1604197086]', headers=[], checksum=1511419003, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=89, timestamp=1604197091703, timestamp_type=0, key=None, value=b'[21, 17, 45, 42, 16, 1604197091]', headers=[], checksum=3289460353, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=90, timestamp=1604197096755, timestamp_type=0, key=None, value=b'[26, 11, 22, 38, 19, 1604197096]', headers=[], checksum=3688538869, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=91, timestamp=1604197101813, timestamp_type=0, key=None, value=b'[48, 19, 43, 49, 14, 1604197101]', headers=[], checksum=2033780257, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=92, timestamp=1604197106837, timestamp_type=0, key=None, value=b'[21, 28, 22, 35, 17, 1604197106]', headers=[], checksum=89310237, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=93, timestamp=1604197111881, timestamp_type=0, key=None, value=b'[20, 45, 24, 25, 49, 1604197111]', headers=[], checksum=2516920470, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=94, timestamp=1604197320537, timestamp_type=0, key=None, value=b'[26, 38, 27, 45, 45, 1604197320]', headers=[], checksum=2925689711, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=95, timestamp=1604197325651, timestamp_type=0, key=None, value=b'[18, 19, 33, 29, 50, 1604197325]', headers=[], checksum=3848090520, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=96, timestamp=1604197330721, timestamp_type=0, key=None, value=b'[19, 22, 18, 30, 18, 1604197330]', headers=[], checksum=3269211119, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=97, timestamp=1604197335804, timestamp_type=0, key=None, value=b'[11, 18, 41, 45, 33, 1604197335]', headers=[], checksum=2700833595, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=98, timestamp=1604197340864, timestamp_type=0, key=None, value=b'[12, 44, 17, 37, 50, 1604197340]', headers=[], checksum=975803796, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=99, timestamp=1604197345891, timestamp_type=0, key=None, value=b'[26, 20, 19, 21, 32, 1604197345]', headers=[], checksum=3682980982, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=100, timestamp=1604197350925, timestamp_type=0, key=None, value=b'[50, 42, 40, 33, 50, 1604197350]', headers=[], checksum=1153330597, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=101, timestamp=1604197355956, timestamp_type=0, key=None, value=b'[48, 47, 24, 29, 20, 1604197355]', headers=[], checksum=3514439192, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=102, timestamp=1604197361024, timestamp_type=0, key=None, value=b'[17, 18, 12, 28, 37, 1604197360]', headers=[], checksum=2259715749, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=103, timestamp=1604197366091, timestamp_type=0, key=None, value=b'[33, 23, 42, 30, 10, 1604197366]', headers=[], checksum=2313006154, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=104, timestamp=1604197371142, timestamp_type=0, key=None, value=b'[22, 36, 16, 28, 49, 1604197371]', headers=[], checksum=1067476040, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=105, timestamp=1604197376197, timestamp_type=0, key=None, value=b'[17, 50, 38, 14, 28, 1604197376]', headers=[], checksum=2240717202, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=106, timestamp=1604197381236, timestamp_type=0, key=None, value=b'[47, 16, 19, 36, 24, 1604197381]', headers=[], checksum=1275241696, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=107, timestamp=1604197386303, timestamp_type=0, key=None, value=b'[10, 44, 12, 28, 33, 1604197386]', headers=[], checksum=1963341409, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=108, timestamp=1604197391352, timestamp_type=0, key=None, value=b'[17, 17, 49, 15, 41, 1604197391]', headers=[], checksum=2532084540, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset
serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=153, timestamp=1604198418255, timestamp_type=0, key=None, value=b'[25, 21, 27, 34, 21, 1604198418]', headers=[], checksum=2372530770, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=154, timestamp=1604198423287, timestamp_type=0, key=None, value=b'[45, 49, 31, 29, 25, 1604198423]', headers=[], checksum=1561082314, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=155, timestamp=1604198428315, timestamp_type=0, key=None, value=b'[29, 29, 47, 33, 36, 1604198428]', headers=[], checksum=185451033, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=156, timestamp=1604198433372, timestamp_type=0, key=None, value=b'[41, 42, 27, 21, 30, 1604198433]', headers=[], checksum=3350632136, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=157, timestamp=1604198438430, timestamp_type=0, key=None, value=b'[26, 35, 31, 34, 31, 1604198438]', headers=[], checksum=3139152087, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=158, timestamp=1604198443484, timestamp_type=0, key=None, value=b'[22, 40, 38, 33, 40, 1604198443]', headers=[], checksum=373960082, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=159, timestamp=1604198448528, timestamp_type=0, key=None, value=b'[26, 14, 21, 43, 47, 1604198448]', headers=[], checksum=1253921538, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=160, timestamp=1604198453575, timestamp_type=0, key=None, value=b'[29, 47, 32, 28, 45, 1604198453]', headers=[], checksum=3571156553, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=161, timestamp=1604198458615, timestamp_type=0, key=None, value=b'[26, 45, 42, 11, 48, 1604198458]', headers=[], checksum=490238313, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=162, timestamp=1604198463666, timestamp_type=0, key=None, value=b'[50, 19, 26, 43, 15, 1604198463]', headers=[], checksum=2659301421, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=163, timestamp=1604198468727, timestamp_type=0, key=None, value=b'[47, 40, 23, 19, 47, 1604198468]', headers=[], checksum=4199791482, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=164, timestamp=1604198473779, timestamp_type=0, key=None, value=b'[46, 25, 16, 31, 12, 1604198473]', headers=[], checksum=3706939345, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=165, timestamp=1604198478834, timestamp_type=0, key=None, value=b'[14, 21, 37, 28, 44, 1604198478]', headers=[], checksum=2407866750, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=166, timestamp=1604198483860, timestamp_type=0, key=None, value=b'[13, 26, 22, 30, 18, 1604198483]', headers=[], checksum=2343864597, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=167, timestamp=1604198488885, timestamp_type=0, key=None, value=b'[45, 39, 39, 12, 37, 1604198488]', headers=[], checksum=3071376145, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=168, timestamp=1604198493944, timestamp_type=0, key=None, value=b'[26, 48, 30, 27, 35, 1604198493]', headers=[], checksum=2933741199, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=169, timestamp=1604198498994, timestamp_type=0, key=None, value=b'[46, 45, 15, 42, 44, 1604198498]', headers=[], checksum=2945780752, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=170, timestamp=1604198504051, timestamp_type=0, key=None, value=b'[42, 21, 28, 39, 50, 1604198504]', headers=[], checksum=1483329650, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=171, timestamp=1604198509097, timestamp_type=0, key=None, value=b'[32, 34, 26, 30, 48, 1604198509]', headers=[], checksum=3333443067, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=172, timestamp=1604198514158, timestamp_type=0, key=None, value=b'[27, 18, 32, 34, 30, 1604198514]', headers=[], checksum=1249755782, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=173, timestamp=1604198519226, timestamp_type=0, key=None, value=b'[30, 40, 19, 16, 43, 1604198519]', headers=[], checksum=2482795799, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=174, timestamp=1604198524298, timestamp_type=0, key=None, value=b'[18, 12, 35, 45, 33, 1604198524]', headers=[], checksum=1869582849, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset
serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=197, timestamp=1604198640492, timestamp_type=0, key=None, value=b'[49, 49, 40, 12, 49, 1604198640]', headers=[], checksum=916775997, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=198, timestamp=1604198645535, timestamp_type=0, key=None, value=b'[17, 10, 48, 47, 30, 1604198645]', headers=[], checksum=1655613258, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=199, timestamp=1604198650619, timestamp_type=0, key=None, value=b'[46, 22, 20, 45, 29, 1604198650]', headers=[], checksum=1975394314, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=200, timestamp=1604198655663, timestamp_type=0, key=None, value=b'[31, 32, 37, 33, 11, 1604198655]', headers=[], checksum=1137400290, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=201, timestamp=1604198660733, timestamp_type=0, key=None, value=b'[25, 37, 43, 12, 10, 1604198660]', headers=[], checksum=2319346197, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=202, timestamp=1604198665756, timestamp_type=0, key=None, value=b'[27, 31, 45, 12, 37, 1604198665]', headers=[], checksum=2902095978, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=203, timestamp=1604198670781, timestamp_type=0, key=None, value=b'[29, 16, 34, 34, 16, 1604198670]', headers=[], checksum=1395046273, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=204, timestamp=1604198675839, timestamp_type=0, key=None, value=b'[22, 46, 13, 40, 22, 1604198675]', headers=[], checksum=1743857515, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=205, timestamp=1604198680894, timestamp_type=0, key=None, value=b'[24, 25, 14, 12, 34, 1604198680]', headers=[], checksum=149382013, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=206, timestamp=1604198685939, timestamp_type=0, key=None, value=b'[24, 41, 11, 28, 34, 1604198685]', headers=[], checksum=2600563381, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=207, timestamp=1604198690988, timestamp_type=0, key=None, value=b'[38, 11, 43, 32, 46, 1604198690]', headers=[], checksum=3512184341, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=208, timestamp=1604198696042, timestamp_type=0, key=None, value=b'[42, 10, 41, 11, 33, 1604198696]', headers=[], checksum=3117979488, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=209, timestamp=1604198701099, timestamp_type=0, key=None, value=b'[33, 37, 29, 20, 29, 1604198701]', headers=[], checksum=2294496949, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=210, timestamp=1604198706158, timestamp_type=0, key=None, value=b'[49, 12, 10, 25, 45, 1604198706]', headers=[], checksum=1913483550, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=211, timestamp=1604198711216, timestamp_type=0, key=None, value=b'[19, 48, 19, 27, 47, 1604198711]', headers=[], checksum=739534439, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=212, timestamp=1604198716272, timestamp_type=0, key=None, value=b'[48, 19, 14, 36, 49, 1604198716]', headers=[], checksum=59263709, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=213, timestamp=1604198721334, timestamp_type=0, key=None, value=b'[41, 22, 50, 47, 10, 1604198721]', headers=[], checksum=1263210962, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=214, timestamp=1604198726362, timestamp_type=0, key=None, value=b'[43, 50, 22, 35, 50, 1604198726]', headers=[], checksum=4030977597, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=215, timestamp=1604198731397, timestamp_type=0, key=None, value=b'[18, 48, 36, 13, 25, 1604198731]', headers=[], checksum=2630492918, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=216, timestamp=1604198736458, timestamp_type=0, key=None, value=b'[17, 33, 13, 21, 19, 1604198736]', headers=[], checksum=79757575, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=217, timestamp=1604198741518, timestamp_type=0, key=None, value=b'[28, 37, 36, 49, 28, 1604198741]', headers=[], checksum=109923290, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=218, timestamp=1604198746567, timestamp_type=0, key=None, value=b'[32, 34, 31, 25, 39, 1604198746]', headers=[], checksum=1532358360, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=219, timestamp=1604198751632, timestamp_type=0, key=None, value=b'[37, 26, 13, 21, 15, 1604198751]', headers=[], checksum=203200373, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=220, timestamp=1604198756697, timestamp_type=0, key=None, value=b'[23, 17, 39, 35, 29, 1604198756]', headers=[], checksum=2092278251, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=221, timestamp=1604198761754, timestamp_type=0, key=None, value=b'[29, 30, 33, 18, 22, 1604198761]', headers=[], checksum=1901272117, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=222, timestamp=1604198766799, timestamp_type=0, key=None, value=b'[43, 30, 13, 36, 16, 1604198766]', headers=[], checksum=742328359, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=223, timestamp=1604198771870, timestamp_type=0, key=None, value=b'[44, 11, 25, 43, 44, 1604198771]', headers=[], checksum=1272894108, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=224, timestamp=1604198776921, timestamp_type=0, key=None, value=b'[31, 42, 18, 15, 23, 1604198776]', headers=[], checksum=2596144230, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=225, timestamp=1604198781974, timestamp_type=0, key=None, value=b'[14, 21, 48, 21, 16, 1604198781]', headers=[], checksum=1962227273, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=226, timestamp=1604198786998, timestamp_type=0, key=None, value=b'[35, 23, 16, 36, 24, 1604198786]', headers=[], checksum=2609528982, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ConsumerRecord(topic='A2Bprocess', partition=0, offset=227, timestamp=1604198792061, timestamp_type=0, key=None, value=b'[43, 14, 16, 12, 30, 1604198792]', headers=[], checksum=3700141933, serialized_key_size=-1, serialized_value_size=32, serialized_header_size=-1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-706a6bcaecb7> in <module>
#     101     #print(consumer)
#     102     fig, ax = init_plots()
# --> 103     consume_messages(consumer, fig, ax)
#     104
#     105
#
# <ipython-input-22-706a6bcaecb7> in consume_messages(consumer, fig, ax)
#      49         end_t = time.time() + 60*2
#      50         f =  0
# ---> 51         for message in consumer:
#      52             print(message)
#      53             data = eval(str(message.value.decode('utf-8')))
#
# ~/.local/lib/python3.8/site-packages/kafka/consumer/group.py in __next__(self)
#    1190             return self.next_v1()
#    1191         else:
# -> 1192             return self.next_v2()
#    1193
#    1194     def next_v2(self):
#
# ~/.local/lib/python3.8/site-packages/kafka/consumer/group.py in next_v2(self)
#    1198                 self._iterator = self._message_generator_v2()
#    1199             try:
# -> 1200                 return next(self._iterator)
#    1201             except StopIteration:
#    1202                 self._iterator = None
#
# ~/.local/lib/python3.8/site-packages/kafka/consumer/group.py in _message_generator_v2(self)
#    1113     def _message_generator_v2(self):
#    1114         timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1115         record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1116         for tp, records in six.iteritems(record_map):
#    1117             # Generators are stateful, and it is possible that the tp / records
#
# ~/.local/lib/python3.8/site-packages/kafka/consumer/group.py in poll(self, timeout_ms, max_records, update_offsets)
#     652         remaining = timeout_ms
#     653         while True:
# --> 654             records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     655             if records:
#     656                 return records
#
# ~/.local/lib/python3.8/site-packages/kafka/consumer/group.py in _poll_once(self, timeout_ms, max_records, update_offsets)
#     699
#     700         timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 701         self._client.poll(timeout_ms=timeout_ms)
#     702         # after the long poll, we should check whether the group needs to rebalance
#     703         # prior to returning data so that the group can stabilize faster
#
# ~/.local/lib/python3.8/site-packages/kafka/client_async.py in poll(self, timeout_ms, future)
#     598                     timeout = max(0, timeout)  # avoid negative timeouts
#     599
# --> 600                 self._poll(timeout / 1000)
#     601
#     602             # called without the lock to avoid deadlock potential
#
# ~/.local/lib/python3.8/site-packages/kafka/client_async.py in _poll(self, timeout)
#     630
#     631         start_select = time.time()
# --> 632         ready = self._selector.select(timeout)
#     633         end_select = time.time()
#     634         if self._sensors:
#
# /usr/lib/python3.8/selectors.py in select(self, timeout)
#     466             ready = []
#     467             try:
# --> 468                 fd_event_list = self._selector.poll(timeout, max_ev)
#     469             except InterruptedError:
#     470                 return ready
#
# KeyboardInterrupt:
